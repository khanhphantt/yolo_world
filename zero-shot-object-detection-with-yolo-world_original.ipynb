# %% [markdown]
# <a href="https://colab.research.google.com/github/khanhphantt/yolo_world/blob/main/zero-shot-object-detection-with-yolo-world_original.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Zero-Shot Object Detection with YOLO-World
# ---
#
# [![GitHub](https://badges.aleen42.com/src/github.svg)](https://github.com/AILab-CVC/YOLO-World)
# [![arXiv](https://img.shields.io/badge/arXiv-2401.17270-b31b1b.svg)](https://arxiv.org/abs/2401.17270)
# [![YouTube](https://badges.aleen42.com/src/youtube.svg)](https://youtu.be/X7gKBGVz4vs)
# [![Roboflow](https://raw.githubusercontent.com/roboflow-ai/notebooks/main/assets/badges/roboflow-blogpost.svg)](https://blog.roboflow.com/what-is-yolo-world/)
#
# YOLO-World was designed to solve a limitation of existing zero-shot object detection models: speed. Whereas other state-of-the-art models use Transformers, a powerful but typically slower architecture, YOLO-World uses the faster CNN-based YOLO architecture.
#
# According to the paper YOLO-World reached between 35.4 AP with 52.0 FPS for the large version and 26.2 AP with 74.1 FPS for the small version. While the V100 is a powerful GPU, achieving such high FPS on any device is impressive.
#
# ![visualization results of referring object detection](https://storage.googleapis.com/com-roboflow-marketing/supervision/cookbooks/yolo-world-visualization-results-of-referring-object-detection.png)

# %% [markdown]
# ## Before you start
#
# Let's make sure that we have access to GPU. We can use `nvidia-smi` command to do that. In case of any problems navigate to `Edit` -> `Notebook settings` -> `Hardware accelerator`, set it to `GPU`, and then click `Save`.

# %%
# !nvidia-smi
# Out:
# Fri May 30 05:44:49 2025
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 550.54.15              Driver Version: 550.54.15      CUDA Version: 12.4     |
# |-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  Tesla T4                       Off |   00000000:00:04.0 Off |                    0 |
# | N/A   51C    P0             26W /   70W |    1400MiB /  15360MiB |      0%      Default |
# |                                         |                        |                  N/A |
# +-----------------------------------------+------------------------+----------------------+
#
# +-----------------------------------------------------------------------------------------+
# | Processes:                                                                              |
# |  GPU   GI   CI        PID   Type   Process name                              GPU Memory |
# |        ID   ID                                                               Usage      |
# |=========================================================================================|
# +-----------------------------------------------------------------------------------------+

# %% [markdown]
# **NOTE:** To make it easier for us to manage datasets, images and models we create a `HOME` constant.

# %%
import os
HOME = os.getcwd()
print(HOME)
# Out:
# /content

# %% [markdown]
# ## Install required packages
#
# In this guide, we utilize two Python packages: `inference`, for executing zero-shot object detection using YOLO-World, and `supervision`, for post-processing and visualizing the detected objects.

# %%
# !pip install inference-gpu[yolo-world]
# Out:
# Requirement already satisfied: inference-gpu[yolo-world] in /usr/local/lib/python3.11/dist-packages (0.50.2)
# Requirement already satisfied: aiortc~=1.9.0 in /usr/local/lib/python3.11/dist-packages (from inference-gpu[yolo-world]) (1.9.0)
# Requirement already satisfied: APScheduler<4.0.0,>=3.10.1 in /usr/local/lib/python3.11/dist-packages (from inference-gpu[yolo-world]) (3.11.0)
# Requirement already satisfied: asyncua~=1.1.5 in /usr/local/lib/python3.11/dist-packages (from inference-gpu[yolo-world]) (1.1.6)
# Requirement already satisfied: cachetools<6.0.0 in /usr/local/lib/python3.11/dist-packages (from inference-gpu[yolo-world]) (5.5.2)
# Requirement already satisfied: cython~=3.0.0 in /usr/local/lib/python3.11/dist-packages (from inference-gpu[yolo-world]) (3.0.12)
# Requirement already satisfied: python-dotenv~=1.0.0 in /usr/local/lib/python3.11/dist-packages (from inference-gpu[yolo-world]) (1.0.1)
# Requirement already satisfied: fastapi<0.111,>=0.100 in /usr/local/lib/python3.11/dist-packages (from inference-gpu[yolo-world]) (0.110.3)
# Requirement already satisfied: numpy<2.3.0,>=2.0.0 in /usr/local/lib/python3.11/dist-packages (from inference-gpu[yolo-world]) (2.0.2)
# Requirement already satisfied: opencv-python<=4.10.0.84,>=4.8.1.78 in /usr/local/lib/python3.11/dist-packages (from inference-gpu[yolo-world]) (4.10.0.84)
# Requirement already satisfied: opencv-contrib-python<=4.10.0.84,>=4.8.1.78 in /usr/local/lib/python3.11/dist-packages (from inference-gpu[yolo-world]) (4.10.0.84)
# Requirement already satisfied: pillow<12.0,>=11.0 in /usr/local/lib/python3.11/dist-packages (from inference-gpu[yolo-world]) (11.2.1)
# Requirement already satisfied: prometheus-fastapi-instrumentator<=6.0.0 in /usr/local/lib/python3.11/dist-packages (from inference-gpu[yolo-world]) (6.0.0)
# Requirement already satisfied: redis~=5.0.0 in /usr/local/lib/python3.11/dist-packages (from inference-gpu[yolo-world]) (5.0.8)
# Requirement already satisfied: requests<3.0.0,>=2.32.0 in /usr/local/lib/python3.11/dist-packages (from inference-gpu[yolo-world]) (2.32.3)
# Requirement already satisfied: rich<13.10.0,>=13.0.0 in /usr/local/lib/python3.11/dist-packages (from inference-gpu[yolo-world]) (13.9.4)
# Requirement already satisfied: supervision<=0.30.0,>=0.25.1 in /usr/local/lib/python3.11/dist-packages (from inference-gpu[yolo-world]) (0.25.1)
# Requirement already satisfied: pybase64~=1.0.0 in /usr/local/lib/python3.11/dist-packages (from inference-gpu[yolo-world]) (1.0.2)
# Requirement already satisfied: scikit-image<=0.25.2,>=0.19.0 in /usr/local/lib/python3.11/dist-packages (from inference-gpu[yolo-world]) (0.25.2)
# Requirement already satisfied: requests-toolbelt~=1.0.0 in /usr/local/lib/python3.11/dist-packages (from inference-gpu[yolo-world]) (1.0.0)
# Requirement already satisfied: wheel<=0.45.1,>=0.38.1 in /usr/local/lib/python3.11/dist-packages (from inference-gpu[yolo-world]) (0.45.1)
# Requirement already satisfied: setuptools>=70.0.0 in /usr/local/lib/python3.11/dist-packages (from inference-gpu[yolo-world]) (75.2.0)
# Requirement already satisfied: networkx<4.0.0,>=3.0.0 in /usr/local/lib/python3.11/dist-packages (from inference-gpu[yolo-world]) (3.4.2)
# Requirement already satisfied: pydantic<2.12.0,>=2.8.0 in /usr/local/lib/python3.11/dist-packages (from inference-gpu[yolo-world]) (2.11.4)
# Requirement already satisfied: pydantic-settings<2.8 in /usr/local/lib/python3.11/dist-packages (from inference-gpu[yolo-world]) (2.7.1)
# Requirement already satisfied: openai<2.0.0,>=1.12.0 in /usr/local/lib/python3.11/dist-packages (from inference-gpu[yolo-world]) (1.81.0)
# Requirement already satisfied: structlog<25.0.0,>=24.1.0 in /usr/local/lib/python3.11/dist-packages (from inference-gpu[yolo-world]) (24.4.0)
# Requirement already satisfied: zxing-cpp~=2.2.0 in /usr/local/lib/python3.11/dist-packages (from inference-gpu[yolo-world]) (2.2.0)
# Requirement already satisfied: boto3<=1.35.60 in /usr/local/lib/python3.11/dist-packages (from inference-gpu[yolo-world]) (1.35.60)
# Requirement already satisfied: typing_extensions<=4.12.2,>=4.8.0 in /usr/local/lib/python3.11/dist-packages (from inference-gpu[yolo-world]) (4.12.2)
# Requirement already satisfied: pydot~=2.0.0 in /usr/local/lib/python3.11/dist-packages (from inference-gpu[yolo-world]) (2.0.0)
# Requirement already satisfied: shapely<2.1.0,>=2.0.4 in /usr/local/lib/python3.11/dist-packages (from inference-gpu[yolo-world]) (2.0.7)
# Requirement already satisfied: tldextract~=5.1.2 in /usr/local/lib/python3.11/dist-packages (from inference-gpu[yolo-world]) (5.1.3)
# Requirement already satisfied: packaging~=24.0 in /usr/local/lib/python3.11/dist-packages (from inference-gpu[yolo-world]) (24.2)
# Requirement already satisfied: anthropic~=0.49.0 in /usr/local/lib/python3.11/dist-packages (from inference-gpu[yolo-world]) (0.49.0)
# Requirement already satisfied: pandas<3.0.0,>=2.2.3 in /usr/local/lib/python3.11/dist-packages (from inference-gpu[yolo-world]) (2.2.3)
# Requirement already satisfied: paho-mqtt~=1.6.1 in /usr/local/lib/python3.11/dist-packages (from inference-gpu[yolo-world]) (1.6.1)
# Requirement already satisfied: pytest<9.0.0,>=8.0.0 in /usr/local/lib/python3.11/dist-packages (from inference-gpu[yolo-world]) (8.3.5)
# Requirement already satisfied: tokenizers<0.22.0,>=0.19.0 in /usr/local/lib/python3.11/dist-packages (from inference-gpu[yolo-world]) (0.21.1)
# Requirement already satisfied: slack-sdk~=3.33.4 in /usr/local/lib/python3.11/dist-packages (from inference-gpu[yolo-world]) (3.33.5)
# Requirement already satisfied: twilio~=9.3.7 in /usr/local/lib/python3.11/dist-packages (from inference-gpu[yolo-world]) (9.3.8)
# Requirement already satisfied: httpx~=0.28.1 in /usr/local/lib/python3.11/dist-packages (from inference-gpu[yolo-world]) (0.28.1)
# Requirement already satisfied: pylogix==1.0.5 in /usr/local/lib/python3.11/dist-packages (from inference-gpu[yolo-world]) (1.0.5)
# Requirement already satisfied: pymodbus<=3.8.3,>=3.6.9 in /usr/local/lib/python3.11/dist-packages (from inference-gpu[yolo-world]) (3.8.3)
# Requirement already satisfied: backoff~=2.2.0 in /usr/local/lib/python3.11/dist-packages (from inference-gpu[yolo-world]) (2.2.1)
# Requirement already satisfied: filelock<=3.17.0,>=3.12.0 in /usr/local/lib/python3.11/dist-packages (from inference-gpu[yolo-world]) (3.17.0)
# Requirement already satisfied: onnxruntime-gpu<1.22.0,>=1.15.1 in /usr/local/lib/python3.11/dist-packages (from inference-gpu[yolo-world]) (1.21.1)
# Requirement already satisfied: docker<8.0.0,>=7.0.0 in /usr/local/lib/python3.11/dist-packages (from inference-gpu[yolo-world]) (7.1.0)
# Requirement already satisfied: click<8.2.0 in /usr/local/lib/python3.11/dist-packages (from inference-gpu[yolo-world]) (8.1.8)
# Requirement already satisfied: typer<=0.12.5,>=0.9.0 in /usr/local/lib/python3.11/dist-packages (from inference-gpu[yolo-world]) (0.12.5)
# Requirement already satisfied: PyYAML~=6.0.0 in /usr/local/lib/python3.11/dist-packages (from inference-gpu[yolo-world]) (6.0.2)
# Requirement already satisfied: tqdm<5.0.0,>=4.0.0 in /usr/local/lib/python3.11/dist-packages (from inference-gpu[yolo-world]) (4.67.1)
# Requirement already satisfied: nvidia-ml-py<13.0.0 in /usr/local/lib/python3.11/dist-packages (from inference-gpu[yolo-world]) (12.575.51)
# Requirement already satisfied: py-cpuinfo~=9.0.0 in /usr/local/lib/python3.11/dist-packages (from inference-gpu[yolo-world]) (9.0.0)
# Requirement already satisfied: aiohttp<=3.10.11,>=3.9.0 in /usr/local/lib/python3.11/dist-packages (from inference-gpu[yolo-world]) (3.10.11)
# Requirement already satisfied: dataclasses-json~=0.6.0 in /usr/local/lib/python3.11/dist-packages (from inference-gpu[yolo-world]) (0.6.7)
# Requirement already satisfied: ultralytics<=8.3.40,>=8.1.27 in /usr/local/lib/python3.11/dist-packages (from inference-gpu[yolo-world]) (8.3.40)
# Requirement already satisfied: dill==0.3.8 in /usr/local/lib/python3.11/dist-packages (from inference-gpu[yolo-world]) (0.3.8)
# Requirement already satisfied: rf-clip==1.1 in /usr/local/lib/python3.11/dist-packages (from inference-gpu[yolo-world]) (1.1)
# Requirement already satisfied: ftfy in /usr/local/lib/python3.11/dist-packages (from rf-clip==1.1->inference-gpu[yolo-world]) (6.3.1)
# Requirement already satisfied: regex in /usr/local/lib/python3.11/dist-packages (from rf-clip==1.1->inference-gpu[yolo-world]) (2024.11.6)
# Requirement already satisfied: torch in /usr/local/lib/python3.11/dist-packages (from rf-clip==1.1->inference-gpu[yolo-world]) (2.6.0+cu124)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.11/dist-packages (from rf-clip==1.1->inference-gpu[yolo-world]) (0.21.0+cu124)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp<=3.10.11,>=3.9.0->inference-gpu[yolo-world]) (2.6.1)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.11/dist-packages (from aiohttp<=3.10.11,>=3.9.0->inference-gpu[yolo-world]) (1.3.2)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp<=3.10.11,>=3.9.0->inference-gpu[yolo-world]) (25.3.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.11/dist-packages (from aiohttp<=3.10.11,>=3.9.0->inference-gpu[yolo-world]) (1.6.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.11/dist-packages (from aiohttp<=3.10.11,>=3.9.0->inference-gpu[yolo-world]) (6.4.4)
# Requirement already satisfied: yarl<2.0,>=1.12.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp<=3.10.11,>=3.9.0->inference-gpu[yolo-world]) (1.20.0)
# Requirement already satisfied: aioice<1.0.0,>=0.9.0 in /usr/local/lib/python3.11/dist-packages (from aiortc~=1.9.0->inference-gpu[yolo-world]) (0.10.1)
# Requirement already satisfied: av<13.0.0,>=9.0.0 in /usr/local/lib/python3.11/dist-packages (from aiortc~=1.9.0->inference-gpu[yolo-world]) (12.3.0)
# Requirement already satisfied: cffi>=1.0.0 in /usr/local/lib/python3.11/dist-packages (from aiortc~=1.9.0->inference-gpu[yolo-world]) (1.17.1)
# Requirement already satisfied: cryptography>=42.0.0 in /usr/local/lib/python3.11/dist-packages (from aiortc~=1.9.0->inference-gpu[yolo-world]) (43.0.3)
# Requirement already satisfied: google-crc32c>=1.1 in /usr/local/lib/python3.11/dist-packages (from aiortc~=1.9.0->inference-gpu[yolo-world]) (1.7.1)
# Requirement already satisfied: pyee>=9.0.0 in /usr/local/lib/python3.11/dist-packages (from aiortc~=1.9.0->inference-gpu[yolo-world]) (13.0.0)
# Requirement already satisfied: pylibsrtp>=0.10.0 in /usr/local/lib/python3.11/dist-packages (from aiortc~=1.9.0->inference-gpu[yolo-world]) (0.12.0)
# Requirement already satisfied: pyopenssl>=24.0.0 in /usr/local/lib/python3.11/dist-packages (from aiortc~=1.9.0->inference-gpu[yolo-world]) (24.2.1)
# Requirement already satisfied: anyio<5,>=3.5.0 in /usr/local/lib/python3.11/dist-packages (from anthropic~=0.49.0->inference-gpu[yolo-world]) (4.9.0)
# Requirement already satisfied: distro<2,>=1.7.0 in /usr/local/lib/python3.11/dist-packages (from anthropic~=0.49.0->inference-gpu[yolo-world]) (1.9.0)
# Requirement already satisfied: jiter<1,>=0.4.0 in /usr/local/lib/python3.11/dist-packages (from anthropic~=0.49.0->inference-gpu[yolo-world]) (0.10.0)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.11/dist-packages (from anthropic~=0.49.0->inference-gpu[yolo-world]) (1.3.1)
# Requirement already satisfied: tzlocal>=3.0 in /usr/local/lib/python3.11/dist-packages (from APScheduler<4.0.0,>=3.10.1->inference-gpu[yolo-world]) (5.3.1)
# Requirement already satisfied: aiofiles in /usr/local/lib/python3.11/dist-packages (from asyncua~=1.1.5->inference-gpu[yolo-world]) (24.1.0)
# Requirement already satisfied: aiosqlite in /usr/local/lib/python3.11/dist-packages (from asyncua~=1.1.5->inference-gpu[yolo-world]) (0.21.0)
# Requirement already satisfied: python-dateutil in /usr/local/lib/python3.11/dist-packages (from asyncua~=1.1.5->inference-gpu[yolo-world]) (2.9.0.post0)
# Requirement already satisfied: pytz in /usr/local/lib/python3.11/dist-packages (from asyncua~=1.1.5->inference-gpu[yolo-world]) (2025.2)
# Requirement already satisfied: sortedcontainers in /usr/local/lib/python3.11/dist-packages (from asyncua~=1.1.5->inference-gpu[yolo-world]) (2.4.0)
# Requirement already satisfied: wait-for2==0.3.2 in /usr/local/lib/python3.11/dist-packages (from asyncua~=1.1.5->inference-gpu[yolo-world]) (0.3.2)
# Requirement already satisfied: botocore<1.36.0,>=1.35.60 in /usr/local/lib/python3.11/dist-packages (from boto3<=1.35.60->inference-gpu[yolo-world]) (1.35.99)
# Requirement already satisfied: jmespath<2.0.0,>=0.7.1 in /usr/local/lib/python3.11/dist-packages (from boto3<=1.35.60->inference-gpu[yolo-world]) (1.0.1)
# Requirement already satisfied: s3transfer<0.11.0,>=0.10.0 in /usr/local/lib/python3.11/dist-packages (from boto3<=1.35.60->inference-gpu[yolo-world]) (0.10.4)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in /usr/local/lib/python3.11/dist-packages (from dataclasses-json~=0.6.0->inference-gpu[yolo-world]) (3.26.1)
# Requirement already satisfied: typing-inspect<1,>=0.4.0 in /usr/local/lib/python3.11/dist-packages (from dataclasses-json~=0.6.0->inference-gpu[yolo-world]) (0.9.0)
# Requirement already satisfied: urllib3>=1.26.0 in /usr/local/lib/python3.11/dist-packages (from docker<8.0.0,>=7.0.0->inference-gpu[yolo-world]) (2.4.0)
# Requirement already satisfied: starlette<0.38.0,>=0.37.2 in /usr/local/lib/python3.11/dist-packages (from fastapi<0.111,>=0.100->inference-gpu[yolo-world]) (0.37.2)
# Requirement already satisfied: certifi in /usr/local/lib/python3.11/dist-packages (from httpx~=0.28.1->inference-gpu[yolo-world]) (2025.4.26)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.11/dist-packages (from httpx~=0.28.1->inference-gpu[yolo-world]) (1.0.9)
# Requirement already satisfied: idna in /usr/local/lib/python3.11/dist-packages (from httpx~=0.28.1->inference-gpu[yolo-world]) (3.10)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.11/dist-packages (from httpcore==1.*->httpx~=0.28.1->inference-gpu[yolo-world]) (0.16.0)
# Requirement already satisfied: coloredlogs in /usr/local/lib/python3.11/dist-packages (from onnxruntime-gpu<1.22.0,>=1.15.1->inference-gpu[yolo-world]) (15.0.1)
# Requirement already satisfied: flatbuffers in /usr/local/lib/python3.11/dist-packages (from onnxruntime-gpu<1.22.0,>=1.15.1->inference-gpu[yolo-world]) (25.2.10)
# Requirement already satisfied: protobuf in /usr/local/lib/python3.11/dist-packages (from onnxruntime-gpu<1.22.0,>=1.15.1->inference-gpu[yolo-world]) (5.29.4)
# Requirement already satisfied: sympy in /usr/local/lib/python3.11/dist-packages (from onnxruntime-gpu<1.22.0,>=1.15.1->inference-gpu[yolo-world]) (1.13.1)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas<3.0.0,>=2.2.3->inference-gpu[yolo-world]) (2025.2)
# Requirement already satisfied: prometheus-client<1.0.0,>=0.8.0 in /usr/local/lib/python3.11/dist-packages (from prometheus-fastapi-instrumentator<=6.0.0->inference-gpu[yolo-world]) (0.22.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.11/dist-packages (from pydantic<2.12.0,>=2.8.0->inference-gpu[yolo-world]) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in /usr/local/lib/python3.11/dist-packages (from pydantic<2.12.0,>=2.8.0->inference-gpu[yolo-world]) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in /usr/local/lib/python3.11/dist-packages (from pydantic<2.12.0,>=2.8.0->inference-gpu[yolo-world]) (0.4.1)
# Requirement already satisfied: pyparsing>=3 in /usr/local/lib/python3.11/dist-packages (from pydot~=2.0.0->inference-gpu[yolo-world]) (3.2.3)
# Requirement already satisfied: iniconfig in /usr/local/lib/python3.11/dist-packages (from pytest<9.0.0,>=8.0.0->inference-gpu[yolo-world]) (2.1.0)
# Requirement already satisfied: pluggy<2,>=1.5 in /usr/local/lib/python3.11/dist-packages (from pytest<9.0.0,>=8.0.0->inference-gpu[yolo-world]) (1.6.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests<3.0.0,>=2.32.0->inference-gpu[yolo-world]) (3.4.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.11/dist-packages (from rich<13.10.0,>=13.0.0->inference-gpu[yolo-world]) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.11/dist-packages (from rich<13.10.0,>=13.0.0->inference-gpu[yolo-world]) (2.19.1)
# Requirement already satisfied: scipy>=1.11.4 in /usr/local/lib/python3.11/dist-packages (from scikit-image<=0.25.2,>=0.19.0->inference-gpu[yolo-world]) (1.15.3)
# Requirement already satisfied: imageio!=2.35.0,>=2.33 in /usr/local/lib/python3.11/dist-packages (from scikit-image<=0.25.2,>=0.19.0->inference-gpu[yolo-world]) (2.37.0)
# Requirement already satisfied: tifffile>=2022.8.12 in /usr/local/lib/python3.11/dist-packages (from scikit-image<=0.25.2,>=0.19.0->inference-gpu[yolo-world]) (2025.5.21)
# Requirement already satisfied: lazy-loader>=0.4 in /usr/local/lib/python3.11/dist-packages (from scikit-image<=0.25.2,>=0.19.0->inference-gpu[yolo-world]) (0.4)
# Requirement already satisfied: contourpy>=1.0.7 in /usr/local/lib/python3.11/dist-packages (from supervision<=0.30.0,>=0.25.1->inference-gpu[yolo-world]) (1.3.2)
# Requirement already satisfied: defusedxml<0.8.0,>=0.7.1 in /usr/local/lib/python3.11/dist-packages (from supervision<=0.30.0,>=0.25.1->inference-gpu[yolo-world]) (0.7.1)
# Requirement already satisfied: matplotlib>=3.6.0 in /usr/local/lib/python3.11/dist-packages (from supervision<=0.30.0,>=0.25.1->inference-gpu[yolo-world]) (3.10.0)
# Requirement already satisfied: requests-file>=1.4 in /usr/local/lib/python3.11/dist-packages (from tldextract~=5.1.2->inference-gpu[yolo-world]) (2.1.0)
# Requirement already satisfied: huggingface-hub<1.0,>=0.16.4 in /usr/local/lib/python3.11/dist-packages (from tokenizers<0.22.0,>=0.19.0->inference-gpu[yolo-world]) (0.31.4)
# Requirement already satisfied: PyJWT<3.0.0,>=2.0.0 in /usr/local/lib/python3.11/dist-packages (from twilio~=9.3.7->inference-gpu[yolo-world]) (2.10.1)
# Requirement already satisfied: aiohttp-retry==2.8.3 in /usr/local/lib/python3.11/dist-packages (from twilio~=9.3.7->inference-gpu[yolo-world]) (2.8.3)
# Requirement already satisfied: shellingham>=1.3.0 in /usr/local/lib/python3.11/dist-packages (from typer<=0.12.5,>=0.9.0->inference-gpu[yolo-world]) (1.5.4)
# Requirement already satisfied: psutil in /usr/local/lib/python3.11/dist-packages (from ultralytics<=8.3.40,>=8.1.27->inference-gpu[yolo-world]) (5.9.5)
# Requirement already satisfied: seaborn>=0.11.0 in /usr/local/lib/python3.11/dist-packages (from ultralytics<=8.3.40,>=8.1.27->inference-gpu[yolo-world]) (0.13.2)
# Requirement already satisfied: ultralytics-thop>=2.0.0 in /usr/local/lib/python3.11/dist-packages (from ultralytics<=8.3.40,>=8.1.27->inference-gpu[yolo-world]) (2.0.14)
# Requirement already satisfied: dnspython>=2.0.0 in /usr/local/lib/python3.11/dist-packages (from aioice<1.0.0,>=0.9.0->aiortc~=1.9.0->inference-gpu[yolo-world]) (2.7.0)
# Requirement already satisfied: ifaddr>=0.2.0 in /usr/local/lib/python3.11/dist-packages (from aioice<1.0.0,>=0.9.0->aiortc~=1.9.0->inference-gpu[yolo-world]) (0.2.0)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.11/dist-packages (from cffi>=1.0.0->aiortc~=1.9.0->inference-gpu[yolo-world]) (2.22)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub<1.0,>=0.16.4->tokenizers<0.22.0,>=0.19.0->inference-gpu[yolo-world]) (2025.3.2)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.11/dist-packages (from markdown-it-py>=2.2.0->rich<13.10.0,>=13.0.0->inference-gpu[yolo-world]) (0.1.2)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.6.0->supervision<=0.30.0,>=0.25.1->inference-gpu[yolo-world]) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.6.0->supervision<=0.30.0,>=0.25.1->inference-gpu[yolo-world]) (4.58.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.6.0->supervision<=0.30.0,>=0.25.1->inference-gpu[yolo-world]) (1.4.8)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil->asyncua~=1.1.5->inference-gpu[yolo-world]) (1.17.0)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from torch->rf-clip==1.1->inference-gpu[yolo-world]) (3.1.6)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch->rf-clip==1.1->inference-gpu[yolo-world]) (12.4.127)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch->rf-clip==1.1->inference-gpu[yolo-world]) (12.4.127)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch->rf-clip==1.1->inference-gpu[yolo-world]) (12.4.127)
# Requirement already satisfied: nvidia-cudnn-cu12==9.1.0.70 in /usr/local/lib/python3.11/dist-packages (from torch->rf-clip==1.1->inference-gpu[yolo-world]) (9.1.0.70)
# Requirement already satisfied: nvidia-cublas-cu12==12.4.5.8 in /usr/local/lib/python3.11/dist-packages (from torch->rf-clip==1.1->inference-gpu[yolo-world]) (12.4.5.8)
# Requirement already satisfied: nvidia-cufft-cu12==11.2.1.3 in /usr/local/lib/python3.11/dist-packages (from torch->rf-clip==1.1->inference-gpu[yolo-world]) (11.2.1.3)
# Requirement already satisfied: nvidia-curand-cu12==10.3.5.147 in /usr/local/lib/python3.11/dist-packages (from torch->rf-clip==1.1->inference-gpu[yolo-world]) (10.3.5.147)
# Requirement already satisfied: nvidia-cusolver-cu12==11.6.1.9 in /usr/local/lib/python3.11/dist-packages (from torch->rf-clip==1.1->inference-gpu[yolo-world]) (11.6.1.9)
# Requirement already satisfied: nvidia-cusparse-cu12==12.3.1.170 in /usr/local/lib/python3.11/dist-packages (from torch->rf-clip==1.1->inference-gpu[yolo-world]) (12.3.1.170)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.6.2 in /usr/local/lib/python3.11/dist-packages (from torch->rf-clip==1.1->inference-gpu[yolo-world]) (0.6.2)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /usr/local/lib/python3.11/dist-packages (from torch->rf-clip==1.1->inference-gpu[yolo-world]) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch->rf-clip==1.1->inference-gpu[yolo-world]) (12.4.127)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch->rf-clip==1.1->inference-gpu[yolo-world]) (12.4.127)
# Requirement already satisfied: triton==3.2.0 in /usr/local/lib/python3.11/dist-packages (from torch->rf-clip==1.1->inference-gpu[yolo-world]) (3.2.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy->onnxruntime-gpu<1.22.0,>=1.15.1->inference-gpu[yolo-world]) (1.3.0)
# Requirement already satisfied: mypy-extensions>=0.3.0 in /usr/local/lib/python3.11/dist-packages (from typing-inspect<1,>=0.4.0->dataclasses-json~=0.6.0->inference-gpu[yolo-world]) (1.1.0)
# Requirement already satisfied: propcache>=0.2.1 in /usr/local/lib/python3.11/dist-packages (from yarl<2.0,>=1.12.0->aiohttp<=3.10.11,>=3.9.0->inference-gpu[yolo-world]) (0.3.1)
# Requirement already satisfied: humanfriendly>=9.1 in /usr/local/lib/python3.11/dist-packages (from coloredlogs->onnxruntime-gpu<1.22.0,>=1.15.1->inference-gpu[yolo-world]) (10.0)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.11/dist-packages (from ftfy->rf-clip==1.1->inference-gpu[yolo-world]) (0.2.13)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->torch->rf-clip==1.1->inference-gpu[yolo-world]) (3.0.2)

# %%
# !pip install supervision
# Out:
# Requirement already satisfied: supervision in /usr/local/lib/python3.11/dist-packages (0.25.1)
# Requirement already satisfied: contourpy>=1.0.7 in /usr/local/lib/python3.11/dist-packages (from supervision) (1.3.2)
# Requirement already satisfied: defusedxml<0.8.0,>=0.7.1 in /usr/local/lib/python3.11/dist-packages (from supervision) (0.7.1)
# Requirement already satisfied: matplotlib>=3.6.0 in /usr/local/lib/python3.11/dist-packages (from supervision) (3.10.0)
# Requirement already satisfied: numpy>=1.21.2 in /usr/local/lib/python3.11/dist-packages (from supervision) (2.0.2)
# Requirement already satisfied: opencv-python>=4.5.5.64 in /usr/local/lib/python3.11/dist-packages (from supervision) (4.10.0.84)
# Requirement already satisfied: pillow>=9.4 in /usr/local/lib/python3.11/dist-packages (from supervision) (11.2.1)
# Requirement already satisfied: pyyaml>=5.3 in /usr/local/lib/python3.11/dist-packages (from supervision) (6.0.2)
# Requirement already satisfied: requests>=2.26.0 in /usr/local/lib/python3.11/dist-packages (from supervision) (2.32.3)
# Requirement already satisfied: scipy<2.0.0,>=1.10.0 in /usr/local/lib/python3.11/dist-packages (from supervision) (1.15.3)
# Requirement already satisfied: tqdm>=4.62.3 in /usr/local/lib/python3.11/dist-packages (from supervision) (4.67.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.6.0->supervision) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.6.0->supervision) (4.58.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.6.0->supervision) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.6.0->supervision) (24.2)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.6.0->supervision) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.6.0->supervision) (2.9.0.post0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests>=2.26.0->supervision) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests>=2.26.0->supervision) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests>=2.26.0->supervision) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests>=2.26.0->supervision) (2025.4.26)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.7->matplotlib>=3.6.0->supervision) (1.17.0)

# %%
# !pip uninstall numpy && pip install "numpy<2.1"
# Out:
# Found existing installation: numpy 2.0.2
# Uninstalling numpy-2.0.2:
#   Would remove:
#     /usr/local/bin/f2py
#     /usr/local/bin/numpy-config
#     /usr/local/lib/python3.11/dist-packages/numpy-2.0.2.dist-info/*
#     /usr/local/lib/python3.11/dist-packages/numpy.libs/libgfortran-040039e1-0352e75f.so.5.0.0
#     /usr/local/lib/python3.11/dist-packages/numpy.libs/libquadmath-96973f99-934c22de.so.0.0.0
#     /usr/local/lib/python3.11/dist-packages/numpy.libs/libscipy_openblas64_-99b71e71.so
#     /usr/local/lib/python3.11/dist-packages/numpy/*
# Proceed (Y/n)? Y
#   Successfully uninstalled numpy-2.0.2
# Collecting numpy<2.1
#   Using cached numpy-2.0.2-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (60 kB)
# Using cached numpy-2.0.2-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (19.5 MB)
# Installing collected packages: numpy
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# google-colab 1.0.0 requires pandas==2.2.2, but you have pandas 2.2.3 which is incompatible.
# datasets 2.14.4 requires dill<0.3.8,>=0.3.0, but you have dill 0.3.8 which is incompatible.
# Successfully installed numpy-2.0.2

# %%
import cv2
import supervision as sv

from tqdm import tqdm
from inference.models import YOLOWorld

# %% [markdown]
# ## Download example data

# %%
# !wget -P {HOME} -q https://media.roboflow.com/notebooks/examples/dog.jpeg
# !wget -P {HOME} -q https://media.roboflow.com/supervision/cookbooks/yellow-filling.mp4

# %%
SOURCE_IMAGE_PATH = f"{HOME}/dog.jpeg"
SOURCE_VIDEO_PATH = f"{HOME}/yellow-filling.mp4"

# %% [markdown]
# **NOTE:** If you want to run the cookbook using your own file as input, simply upload video to Google Colab and replace `SOURCE_IMAGE_PATH` and `SOURCE_VIDEO_PATH` with the path to your file.

# %% [markdown]
# ## Run Object Detection
#
# The Inference package provides the YOLO-World model in three versions: `S`, `M`, and `L`. You can load them by defining model_id as `yolo_world/s`, `yolo_world/m`, and `yolo_world/l`, respectively. The `ROBOFLOW_API_KEY` is not required to utilize this model.

# %%
model = YOLOWorld(model_id="yolo_world/l")

# %% [markdown]
# YOLO-World is a zero-shot model, enabling object detection without any training. You only need to define a prompt as a list of classes (things) you are searching for.

# %%
classes = ["person", "backpack", "dog", "eye", "nose", "ear", "tongue"]
model.set_classes(classes)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-cc9f9500b2ca> in <cell line: 0>()
#       1 classes = ["person", "backpack", "dog", "eye", "nose", "ear", "tongue"]
# ----> 2 model.set_classes(classes)
#
# NameError: name 'model' is not defined

# %% [markdown]
# We perform detection on our sample image. Then, we convert the result into a [`sv.Detections`](https://supervision.roboflow.com/latest/detection/core/) object, which will be useful in the later parts of the cookbook.

# %%
image = cv2.imread(SOURCE_IMAGE_PATH)
results = model.infer(image)
detections = sv.Detections.from_inference(results)

# %% [markdown]
# The results we've obtained can be easily visualized with [`sv.BoundingBoxAnnotator`](https://supervision.roboflow.com/latest/annotators/#supervision.annotators.core.BoundingBoxAnnotator) and [`sv.LabelAnnotator`](https://supervision.roboflow.com/latest/annotators/#supervision.annotators.core.LabelAnnotator). We can adjust parameters such as line thickness, text scale, line and text color allowing for a highly tailored visualization experience.

# %%
BOUNDING_BOX_ANNOTATOR = sv.BoundingBoxAnnotator(thickness=2)
LABEL_ANNOTATOR = sv.LabelAnnotator(text_thickness=2, text_scale=1, text_color=sv.Color.BLACK)

# %%
annotated_image = image.copy()
annotated_image = BOUNDING_BOX_ANNOTATOR.annotate(annotated_image, detections)
annotated_image = LABEL_ANNOTATOR.annotate(annotated_image, detections)
sv.plot_image(annotated_image, (10, 10))

# %% [markdown]
# ## Adjusting Confidence Level

# %% [markdown]
# Note that many classes from our prompt were not detected. This is because the default confidence threshold in Inference is set to `0.5`. Let's try significantly lowering this value. We've observed that the confidence returned by YOLO-World is significantly lower when querying for classes outside the [COCO](https://universe.roboflow.com/microsoft/coco) dataset.

# %%
image = cv2.imread(SOURCE_IMAGE_PATH)
results = model.infer(image, confidence=0.003)
detections = sv.Detections.from_inference(results)

# %% [markdown]
# By default, `sv.LabelAnnotator` displays only the names of objects. To also view the confidence levels associated with each detection, we must define custom `labels` and pass them to `sv.LabelAnnotator`.

# %%
labels = [
    f"{classes[class_id]} {confidence:0.3f}"
    for class_id, confidence
    in zip(detections.class_id, detections.confidence)
]

annotated_image = image.copy()
annotated_image = BOUNDING_BOX_ANNOTATOR.annotate(annotated_image, detections)
annotated_image = LABEL_ANNOTATOR.annotate(annotated_image, detections, labels=labels)
sv.plot_image(annotated_image, (10, 10))

# %% [markdown]
# ## Using Non-Max Suppression (NMS) to Eliminate Double Detections
#
# To eliminate duplicates, we will use [Non-Max Suppression (NMS)](https://blog.roboflow.com/how-to-code-non-maximum-suppression-nms-in-plain-numpy). NMS evaluates the extent to which detections overlap using the Intersection over Union metric and, upon exceeding a defined threshold, treats them as duplicates. Duplicates are then discarded, starting with those of the lowest confidence. The value should be within the range `[0, 1]`. The smaller the value, the more restrictive the NMS.

# %%
image = cv2.imread(SOURCE_IMAGE_PATH)
results = model.infer(image, confidence=0.003)
detections = sv.Detections.from_inference(results).with_nms(threshold=0.1)

# %%
labels = [
    f"{classes[class_id]} {confidence:0.3f}"
    for class_id, confidence
    in zip(detections.class_id, detections.confidence)
]

annotated_image = image.copy()
annotated_image = BOUNDING_BOX_ANNOTATOR.annotate(annotated_image, detections)
annotated_image = LABEL_ANNOTATOR.annotate(annotated_image, detections, labels=labels)
sv.plot_image(annotated_image, (10, 10))

# %% [markdown]
# ## Video Processing

# %% [markdown]
# The [`get_video_frames_generator`](https://supervision.roboflow.com/latest/utils/video/#supervision.utils.video.get_video_frames_generator) enables us to easily iterate over video frames. Let's create a video generator for our sample input file and display its first frame on the screen.

# %%
generator = sv.get_video_frames_generator(SOURCE_VIDEO_PATH)
frame = next(generator)

sv.plot_image(frame, (10, 10))

# %% [markdown]
# Let's update our list of classes. This time we are looking for `yellow filling`. The rest of the code performing detection, filtering and visualization remains unchanged.

# %%
classes = ["yellow filling"]
model.set_classes(classes)

# %%
results = model.infer(frame, confidence=0.002)
detections = sv.Detections.from_inference(results).with_nms(threshold=0.1)

# %%
annotated_image = frame.copy()
annotated_image = BOUNDING_BOX_ANNOTATOR.annotate(annotated_image, detections)
annotated_image = LABEL_ANNOTATOR.annotate(annotated_image, detections)
sv.plot_image(annotated_image, (10, 10))

# %% [markdown]
# ## Filtering Detectuions by Area

# %% [markdown]
# Our prompt allowed us to locate all filled holes, but we also accidentally marked the entire high-level element. To address this issue, we'll filter detections based on their relative area in relation to the entire video frame. If a detection occupies more than 10% of the frame's total area, it will be discarded.

# %% [markdown]
# We can use [`VideoInfo.from_video_path`](https://supervision.roboflow.com/develop/utils/video/#supervision.utils.video.VideoInfo) to learn basic information about our video, such as duration, resolution, or FPS.

# %%
video_info = sv.VideoInfo.from_video_path(SOURCE_VIDEO_PATH)
video_info
# Out:
# VideoInfo(width=1280, height=720, fps=25, total_frames=442)

# %% [markdown]
# Knowing the frame's resolution allows us to easily calculate its total area, expressed in pixels.

# %%
width, height = video_info.resolution_wh
frame_area = width * height
frame_area
# Out:
# 921600

# %% [markdown]
# On the other hand, by using [`sv.Detections.area`](https://supervision.roboflow.com/develop/detection/core/#supervision.detection.core.Detections.area) property, we can learn the area of each individual bounding box.

# %%
results = model.infer(frame, confidence=0.002)
detections = sv.Detections.from_inference(results).with_nms(threshold=0.1)
detections.area
# Out:
# array([ 7.5408e+05])

# %% [markdown]
# Now, we can combine these two pieces of information to construct a filtering condition for detections with an area greater than 10% of the entire frame.

# %%
(detections.area / frame_area) < 0.10
# Out:
# array([False])

# %%
detections = detections[(detections.area / frame_area) < 0.10]

annotated_image = frame.copy()
annotated_image = BOUNDING_BOX_ANNOTATOR.annotate(annotated_image, detections)
annotated_image = LABEL_ANNOTATOR.annotate(annotated_image, detections)
sv.plot_image(annotated_image, (10, 10))

# %% [markdown]
# ## Final Result

# %% [markdown]
# Finally, we are ready to process our entire video. Now in truth we can appreciate the speed of YOLO-World.

# %%
TARGET_VIDEO_PATH = f"{HOME}/yellow-filling-output.mp4"

# %%
frame_generator = sv.get_video_frames_generator(SOURCE_VIDEO_PATH)
video_info = sv.VideoInfo.from_video_path(SOURCE_VIDEO_PATH)

width, height = video_info.resolution_wh
frame_area = width * height
frame_area

with sv.VideoSink(target_path=TARGET_VIDEO_PATH, video_info=video_info) as sink:
    for frame in tqdm(frame_generator, total=video_info.total_frames):
        results = model.infer(frame, confidence=0.002)
        detections = sv.Detections.from_inference(results).with_nms(threshold=0.1)
        detections = detections[(detections.area / frame_area) < 0.10]

        annotated_frame = frame.copy()
        annotated_frame = BOUNDING_BOX_ANNOTATOR.annotate(annotated_frame, detections)
        annotated_frame = LABEL_ANNOTATOR.annotate(annotated_frame, detections)
        sink.write_frame(annotated_frame)
# Out:
# 100%|██████████| 442/442 [00:23<00:00, 18.43it/s]
